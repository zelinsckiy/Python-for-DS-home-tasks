# %% [markdown]
# <a href="https://colab.research.google.com/github/zelinsckiy/Python-for-DS-home-tasks/blob/main/Copy_of_HW4_%D0%A6%D0%B8%D0%BA%D0%BB_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Цикл for - базовий**
#
# Використовуючи цикл `for`, виведіть числа від 1 до 7 включно використовуючи функцію range.

# %%
for i in range(1, 8):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
#знайшов другий спосіб вирішення завдання, без функції range
numbers = [1, 2, 3, 4, 5, 6, 7]
for n in numbers:
  print(n)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# ---
#
# **2. Цикл for по списку**
#
# Дано список:

# %%
names = ["Олег", "Анна", "Іван", "Марія"]

# %% [markdown]
# Використовуючи цикл, виведіть кожне ім'я з привітанням: "Привіт, [ім'я]!"

# %%
for n in names:
  print(f"Привіт,", n)
# Out:
# Привіт, Олег
# Привіт, Анна
# Привіт, Іван
# Привіт, Марія

# %% [markdown]
# ---
#
# **3. Цикл з enumerate**
#
# Дано список оцінок:

# %%
grades = [85, 92, 78, 95, 88]

# %% [markdown]
# Використовуючи `enumerate`, виведіть кожну оцінку з номером: "Студент 1: 85 балів"

# %%
indeces = []
for i, grade in enumerate(grades):
  print(f"Студент", i + 1, grade, "балів")
# Out:
# Студент 1 85 балів
# Студент 2 92 балів
# Студент 3 78 балів
# Студент 4 95 балів
# Студент 5 88 балів

# %% [markdown]
# **4. Сума парних чисел**
#
# Напишіть програму, яка обчислює суму всіх парних чисел від 1 до 20 включно.

# %%
total = 0

for i in range(2, 21, 2):
    total = total + i

print(total)
# Out:
# 110
