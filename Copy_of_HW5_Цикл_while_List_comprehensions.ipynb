# %% [markdown]
# <a href="https://colab.research.google.com/github/zelinsckiy/Python-for-DS-home-tasks/blob/main/Copy_of_HW5_%D0%A6%D0%B8%D0%BA%D0%BB_while_List_comprehensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Цикл while**
#
# Задано змінну `counter`, яка рівна -3.
#
# Напишіть програму, використовуючи `while`, яка в циклі додає до змінної `counter` +1 і зупиняється, коли змінна `counter` стане суворо більше за 5. На кожній ітерації циклу виводьте значення змінної `counter`.

# %%
counter = -3
while counter < 5:
  counter += 1
  print(counter)
# Out:
# -2
# -1
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ---
#
# **2. List comprehension - прості операції**
#
# Дано список чисел:

# %%
numbers = [11, 4, 9, 16, 7, 5]

# %% [markdown]
# Створіть нові списки використовуючи list comprehension, які містять (кожен пункт оцінюється в 0.5 бала):
# - Квадрати всіх чисел
# - Тільки парні числа
# - Всі числа помножені на 10
#
# Виведіть новоутворені списки.

# %%
#Квадрати всіх чисел
squares = [i ** 2
           for i in numbers]
print(squares)
# Out:
# [121, 16, 81, 256, 49, 25]

# %%
#Тільки парні числа
for i in numbers:
  if i % 2 == 0:
    print(i)
# Out:
# 4
# 16

# %%
#Всі числа помножені на 10
multiple = [i * 10
            for i in numbers]
print(multiple)
# Out:
# [110, 40, 90, 160, 70, 50]

# %% [markdown]
# ---
#
# **3. List comprehension - комбінована логіка**
#
# Дано список чисел від 1 до 10. Створіть новий список, де виконується наступна логіка:
# - Якщо число парне - помножте його на 2
# - Якщо непарне - віднімніть 1
#
# Виведіть результуючий список на екран.

# %%
numbers = list(range(1, 11))

# %%
nlist = [i * 2
         if i % 2 == 0
         else i - 1
         for i in numbers]
print(nlist)
# Out:
# [10, 8, 8, 32, 6, 4]
